# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import time

import random

import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

import csv
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

STOPWORDS = set(stopwords.words('english'))

print(tf.__version__)
# Out:
# 2.1.0
# [nltk_data] Downloading package stopwords to /home/robin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Function to scrape job openings from Indeed

# %%
def scraper(job_titles):

    job_openings = [] # list with job opening text
    labels = [] # list with job opening labels

    main = "https://www.indeed.com" # main indeed url

    for item in job_titles:

        job = '"' + item.replace(" ", "+") + '"' # replace space in job title with dash

        print(job)

        for number in range(0, 2000, 10): # will scrape 500 job openings

            print(f"starting first {number} of {item}")

            url = f"{main}/jobs?q={job}&start={number}" # compile job specific url

            print(url)
            
            try:
                page = requests.get(url) # request url
            except:
                break
                print("An error occured")
            
            time.sleep(2)

            soup = BeautifulSoup(page.content, "html.parser") # parse the page with beautifulsoup

            links = [a['href'] for a in soup.find_all('a', href=True)] # find all the urls on the page

            match_links = [main+s for s in links if "rc/clk?jk=" in s] # find all the urls that link to job page
            
            print(len(match_links))

            for link in match_links: # loop through the 10 job ad urls on the page
                
                print(link)
                
                try:
                    job_page = requests.get(link) # request the job ad url
                except:
                    break
                    print("An error occured")
                    
                time.sleep(3) # wait a few seconds to not overlad server
                job_soup = BeautifulSoup(job_page.content, "html.parser") # parse the page

                for element in job_soup.find_all('div', attrs={"class":"jobsearch-jobDescriptionText"}): # loop through the job text
                    text = element.get_text(separator = " ").replace("\n","") # remove all tags from job text
                    job_openings.append(text) # append job text tot job_openings
                    labels.append(item) # append job title

            if len(match_links) < 5: # breaks the loop if we are at the end of the # of jobs
                break                    
    
    return job_openings, labels

# %% [markdown]
# The scraper can take a list with any number of job titles and will take the first 500 job openings.

# %%
job_openings = ["data hero",
                "data scientist",
                "data analyst",
                "business analyst",
                "data engineer",
                "machine learning engineer",
                "data architect"]

jobs, labels = scraper(job_openings)

# %%
job_openings2 = [# "data hero",
                # "data scientist",
                "data analyst",
                "business analyst",
                "data engineer",
                "machine learning engineer",
                "data architect"]

jobs2, labels2 = scraper(job_openings2)
# Out:
# "data+analyst"
# starting first 0 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=0
# 10
# https://www.indeed.com/rc/clk?jk=b9ab2261f8c09965&fccid=7890456d161b1285&vjs=3
# https://www.indeed.com/rc/clk?jk=058a5d8b147b3117&fccid=d5998a961671e818&vjs=3
# https://www.indeed.com/rc/clk?jk=3819d9f7ce42b610&fccid=10b1f58e33d8d2a8&vjs=3
# https://www.indeed.com/rc/clk?jk=b967baa627475133&fccid=e74b668d26ed43b3&vjs=3
# https://www.indeed.com/rc/clk?jk=7ec66a909282b0f4&fccid=66d394411dd2efad&vjs=3
# https://www.indeed.com/rc/clk?jk=57125117d2b4b0f6&fccid=ae6e171391e978d5&vjs=3
# https://www.indeed.com/rc/clk?jk=2f69b7d86ea813ab&fccid=2f1303bf45b0d7af&vjs=3
# https://www.indeed.com/rc/clk?jk=6e9cdfd005d5d84f&fccid=de21c88cd020293b&vjs=3
# https://www.indeed.com/rc/clk?jk=adc8162797f38f34&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=730d4f5920e34bfa&fccid=d85dc84e1f190d4a&vjs=3
# starting first 10 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=10
# 9
# https://www.indeed.com/rc/clk?jk=9e0179a1255be059&fccid=6b91af7c75a0855d&vjs=3
# https://www.indeed.com/rc/clk?jk=672c2414c9da98e5&fccid=c0434cfcd399237e&vjs=3
# https://www.indeed.com/rc/clk?jk=5a20b9eaab23072e&fccid=bc51f56762438d6f&vjs=3
# https://www.indeed.com/rc/clk?jk=bc6e5a4db823e279&fccid=4afc115df6b0f70b&vjs=3
# https://www.indeed.com/rc/clk?jk=395d980c09d8223d&fccid=a00e0f48d2d490c3&vjs=3
# https://www.indeed.com/rc/clk?jk=d2467dcf93575812&fccid=679aea3b529f8f45&vjs=3
# https://www.indeed.com/rc/clk?jk=3f783c76ad89b06f&fccid=cb8355041fe4a920&vjs=3
# https://www.indeed.com/rc/clk?jk=d1c3d05316be410d&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=4674a8266acf5e46&fccid=ae3ba26fed950f3e&vjs=3
# starting first 20 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=20
# 10
# https://www.indeed.com/rc/clk?jk=dc122b0bf9be8828&fccid=6f05714302f19158&vjs=3
# https://www.indeed.com/rc/clk?jk=57125117d2b4b0f6&fccid=ae6e171391e978d5&vjs=3
# https://www.indeed.com/rc/clk?jk=b7deea01ba0857dd&fccid=43014b1412e0a7b6&vjs=3
# https://www.indeed.com/rc/clk?jk=45d7f22d2d4c3108&fccid=e2046655ee5b8a6a&vjs=3
# https://www.indeed.com/rc/clk?jk=b967baa627475133&fccid=e74b668d26ed43b3&vjs=3
# https://www.indeed.com/rc/clk?jk=b7390c5547f56dc6&fccid=47538b950e1fe799&vjs=3
# https://www.indeed.com/rc/clk?jk=d2467dcf93575812&fccid=679aea3b529f8f45&vjs=3
# https://www.indeed.com/rc/clk?jk=b9ca4a1d90a06ba4&fccid=db70737d31eac471&vjs=3
# https://www.indeed.com/rc/clk?jk=0b06d6f73de3b31d&fccid=7cc9cddddb564bb9&vjs=3
# https://www.indeed.com/rc/clk?jk=049fd54a53065dc9&fccid=975a4c6e95a58ae2&vjs=3
# starting first 30 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=30
# 10
# https://www.indeed.com/rc/clk?jk=dc122b0bf9be8828&fccid=6f05714302f19158&vjs=3
# https://www.indeed.com/rc/clk?jk=e2f326362ac3a2c5&fccid=c0434cfcd399237e&vjs=3
# https://www.indeed.com/rc/clk?jk=47149fcf55d468f0&fccid=8b11bd0c33da064e&vjs=3
# https://www.indeed.com/rc/clk?jk=c04a8d5fa0e7869c&fccid=ed3db458f28ca6b3&vjs=3
# https://www.indeed.com/rc/clk?jk=049fd54a53065dc9&fccid=975a4c6e95a58ae2&vjs=3
# https://www.indeed.com/rc/clk?jk=24418bfa3f448628&fccid=db8116684547d327&vjs=3
# https://www.indeed.com/rc/clk?jk=1636faa0308fd08f&fccid=1577085fc2290983&vjs=3
# https://www.indeed.com/rc/clk?jk=19ad04c541d37f11&fccid=ff513d4351456de2&vjs=3
# https://www.indeed.com/rc/clk?jk=68d8cabf5bf8d900&fccid=955f2d9ff468b2fe&vjs=3
# https://www.indeed.com/rc/clk?jk=3c025002e574c292&fccid=d2c6abf8a785fc40&vjs=3
# starting first 40 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=40
# 10
# https://www.indeed.com/rc/clk?jk=9974950973fc360e&fccid=22c2c66e6ebb2f6b&vjs=3
# https://www.indeed.com/rc/clk?jk=4fb889570fa2f8bb&fccid=2394c9d5d73fdfc5&vjs=3
# https://www.indeed.com/rc/clk?jk=3c025002e574c292&fccid=d2c6abf8a785fc40&vjs=3
# https://www.indeed.com/rc/clk?jk=81de26cdeb635ef2&fccid=b8630c7613683006&vjs=3
# https://www.indeed.com/rc/clk?jk=fb787822fdc8634a&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=5111df921e6899f2&fccid=62962e7b20e362c4&vjs=3
# https://www.indeed.com/rc/clk?jk=e2f326362ac3a2c5&fccid=c0434cfcd399237e&vjs=3
# https://www.indeed.com/rc/clk?jk=bc9f257bb290958c&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=5622723d2b09fd30&fccid=d7bd51c63266d60a&vjs=3
# https://www.indeed.com/rc/clk?jk=2d0658d38aa3bbcb&fccid=27a2140ddcca6697&vjs=3
# starting first 50 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=50
# 10
# https://www.indeed.com/rc/clk?jk=eab16dd7fe4103d2&fccid=16c1626cef745f92&vjs=3
# https://www.indeed.com/rc/clk?jk=1c87abe04e3c9895&fccid=4e68af4ff90cab8e&vjs=3
# https://www.indeed.com/rc/clk?jk=e4315add2a1c7663&fccid=aef928e89977f7f0&vjs=3
# https://www.indeed.com/rc/clk?jk=860135e8d701d002&fccid=06c2388fc3e54c23&vjs=3
# https://www.indeed.com/rc/clk?jk=47149fcf55d468f0&fccid=8b11bd0c33da064e&vjs=3
# https://www.indeed.com/rc/clk?jk=9be15e70cd0f5195&fccid=6cd80bea00f0e9e3&vjs=3
# https://www.indeed.com/rc/clk?jk=998efa3408a2bd58&fccid=c4edd35d91e8a141&vjs=3
# https://www.indeed.com/rc/clk?jk=ab29bc019a081f31&fccid=73f28c37335d8899&vjs=3
# https://www.indeed.com/rc/clk?jk=19ad04c541d37f11&fccid=ff513d4351456de2&vjs=3
# https://www.indeed.com/rc/clk?jk=e7f096160c8df047&fccid=2e1a7c477333437a&vjs=3
# starting first 60 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=60
# 10
# https://www.indeed.com/rc/clk?jk=b77d67c7a6f69ca6&fccid=d4f9c2eaf069523f&vjs=3
# https://www.indeed.com/rc/clk?jk=14762009757e4bf3&fccid=9784ae78e9834539&vjs=3
# https://www.indeed.com/rc/clk?jk=35076b413ad59e8f&fccid=c3924b528c57195b&vjs=3
# https://www.indeed.com/rc/clk?jk=bb044326303f093d&fccid=71147e0539a0a1b7&vjs=3
# https://www.indeed.com/rc/clk?jk=998efa3408a2bd58&fccid=c4edd35d91e8a141&vjs=3
# https://www.indeed.com/rc/clk?jk=19ad04c541d37f11&fccid=ff513d4351456de2&vjs=3
# https://www.indeed.com/rc/clk?jk=d207cc8e13e389ed&fccid=bba15db4d8763697&vjs=3
# https://www.indeed.com/rc/clk?jk=94adb2025c47f007&fccid=db70737d31eac471&vjs=3
# https://www.indeed.com/rc/clk?jk=e4315add2a1c7663&fccid=aef928e89977f7f0&vjs=3
# https://www.indeed.com/rc/clk?jk=3d7a19f731e68eef&fccid=fe2d21eef233e94a&vjs=3
# starting first 70 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=70
# 10
# https://www.indeed.com/rc/clk?jk=23f80d8bf722b148&fccid=7fc6d3992188a532&vjs=3
# https://www.indeed.com/rc/clk?jk=5792af9c68e5604a&fccid=d25525f95db539b9&vjs=3
# https://www.indeed.com/rc/clk?jk=19a2b66babd75b5e&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=b0ba35d4d3f1ec25&fccid=39001127b46d3ede&vjs=3
# https://www.indeed.com/rc/clk?jk=77f0b2c274458818&fccid=9b77e2b0ccfb3838&vjs=3
# https://www.indeed.com/rc/clk?jk=ab29bc019a081f31&fccid=73f28c37335d8899&vjs=3
# https://www.indeed.com/rc/clk?jk=62c9c409864b941e&fccid=adbe87789e71ebaf&vjs=3
# https://www.indeed.com/rc/clk?jk=3f783c76ad89b06f&fccid=cb8355041fe4a920&vjs=3
# https://www.indeed.com/rc/clk?jk=a38937917eaefff2&fccid=e228a3c78d0f7f13&vjs=3
# https://www.indeed.com/rc/clk?jk=96eaec9f74594e56&fccid=7559c43e69781c12&vjs=3
# starting first 80 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=80
# 10
# https://www.indeed.com/rc/clk?jk=6be938e1ab97c55c&fccid=8009d67e70703a78&vjs=3
# https://www.indeed.com/rc/clk?jk=bf4bf05d45cce9f0&fccid=45056d760b7d9d86&vjs=3
# https://www.indeed.com/rc/clk?jk=2532431132ffbda1&fccid=30c994b6c2f39768&vjs=3
# https://www.indeed.com/rc/clk?jk=e9dfc0985ef98a44&fccid=a4e4e2eaf26690c9&vjs=3
# https://www.indeed.com/rc/clk?jk=24418bfa3f448628&fccid=db8116684547d327&vjs=3
# https://www.indeed.com/rc/clk?jk=5f691586d69f6d10&fccid=d25525f95db539b9&vjs=3
# https://www.indeed.com/rc/clk?jk=d31fc1da00ac8a00&fccid=2df6a1e69a70a1e7&vjs=3
# https://www.indeed.com/rc/clk?jk=63b61a7a087c5fca&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=fd746ccc9251f231&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=c9b1a1cdd887b87c&fccid=f01ecdb353459ddd&vjs=3
# starting first 90 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=90
# 10
# https://www.indeed.com/rc/clk?jk=02719aaec5f0cdc9&fccid=5b2f9eaa91cb3370&vjs=3
# https://www.indeed.com/rc/clk?jk=411a804aa359aea6&fccid=7fc6d3992188a532&vjs=3
# https://www.indeed.com/rc/clk?jk=ad3eb571e8a624fc&fccid=a38efa13f477f802&vjs=3
# https://www.indeed.com/rc/clk?jk=44f54faa60626e45&fccid=3df1e2a5808020f0&vjs=3
# https://www.indeed.com/rc/clk?jk=fe3e5c324c8a1d35&fccid=0f8d26ec6e64e7ed&vjs=3
# https://www.indeed.com/rc/clk?jk=7ac504066e319539&fccid=008026d8dc2aa7bd&vjs=3
# https://www.indeed.com/rc/clk?jk=d62541d01cbb05d1&fccid=bba15db4d8763697&vjs=3
# https://www.indeed.com/rc/clk?jk=fa85fb93709b0184&fccid=76d3630986f5b206&vjs=3
# https://www.indeed.com/rc/clk?jk=e630740301b166e5&fccid=f4d8d9827523c093&vjs=3
# https://www.indeed.com/rc/clk?jk=bdf917ce016c840e&fccid=ec798be206d0335c&vjs=3
# starting first 100 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=100
# 10
# https://www.indeed.com/rc/clk?jk=d207cc8e13e389ed&fccid=bba15db4d8763697&vjs=3
# https://www.indeed.com/rc/clk?jk=a1cd7c5d6e24488e&fccid=2150e83695978641&vjs=3
# https://www.indeed.com/rc/clk?jk=54dd8869dbe7bd7a&fccid=519cd80cc4a237e4&vjs=3
# https://www.indeed.com/rc/clk?jk=803066ef97bc0914&fccid=6f28e45337f5b8ff&vjs=3
# https://www.indeed.com/rc/clk?jk=3b5bcfe46b0999c7&fccid=56c25448bab54e90&vjs=3
# https://www.indeed.com/rc/clk?jk=26656ff71f1d9c75&fccid=e57932d197e4d8d0&vjs=3
# https://www.indeed.com/rc/clk?jk=b7390c5547f56dc6&fccid=47538b950e1fe799&vjs=3
# https://www.indeed.com/rc/clk?jk=de9f7381108f2c64&fccid=475449500ecde065&vjs=3
# https://www.indeed.com/rc/clk?jk=55b74e789c90b5df&fccid=5a599bb89ab2a26a&vjs=3
# https://www.indeed.com/rc/clk?jk=05d9a7e42a0d5f80&fccid=a3a205eec2c5353a&vjs=3
# starting first 110 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=110
# 10
# https://www.indeed.com/rc/clk?jk=58abf555bc95a0fa&fccid=f770da67b3b51c62&vjs=3
# https://www.indeed.com/rc/clk?jk=05d9a7e42a0d5f80&fccid=a3a205eec2c5353a&vjs=3
# https://www.indeed.com/rc/clk?jk=67adf6c115a96042&fccid=fa691bd7d26474a1&vjs=3
# https://www.indeed.com/rc/clk?jk=a38937917eaefff2&fccid=e228a3c78d0f7f13&vjs=3
# https://www.indeed.com/rc/clk?jk=65eb6c9e8aeed7af&fccid=3d93143c99ff89a3&vjs=3
# https://www.indeed.com/rc/clk?jk=e0261e8819c21ec5&fccid=17e2b725ef2849b8&vjs=3
# https://www.indeed.com/rc/clk?jk=d0914096b5c55b9e&fccid=d96bcd743d670b9c&vjs=3
# https://www.indeed.com/rc/clk?jk=b7deea01ba0857dd&fccid=43014b1412e0a7b6&vjs=3
# https://www.indeed.com/rc/clk?jk=3e4e8bb9940f9691&fccid=dbe97974d004cd2e&vjs=3
# https://www.indeed.com/rc/clk?jk=0c5a3a10925d44b6&fccid=e3a31b16c7259ff7&vjs=3
# starting first 120 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=120
# 10
# https://www.indeed.com/rc/clk?jk=ce664725e926ab67&fccid=b1eb6c2b305e15db&vjs=3
# https://www.indeed.com/rc/clk?jk=dc09c7cc04bc44af&fccid=aed1c2970bb86669&vjs=3
# https://www.indeed.com/rc/clk?jk=e0f5f7584523081a&fccid=59c8e3e7017ea02a&vjs=3
# https://www.indeed.com/rc/clk?jk=1c1070b7f628167a&fccid=30c994b6c2f39768&vjs=3
# https://www.indeed.com/rc/clk?jk=06b9e1bd99e47632&fccid=9c2be00e2f57adbd&vjs=3
# https://www.indeed.com/rc/clk?jk=01a77882e3fdb121&fccid=80d51e111d62ec5d&vjs=3
# https://www.indeed.com/rc/clk?jk=c76615278e740b08&fccid=73e7cfa1796d463f&vjs=3
# https://www.indeed.com/rc/clk?jk=1a1f0fe92a5ca3f6&fccid=565401dac7aa5fae&vjs=3
# https://www.indeed.com/rc/clk?jk=e7f5d24689e509d2&fccid=1850f361f1d8cab4&vjs=3
# https://www.indeed.com/rc/clk?jk=cedec3ad4f22493d&fccid=3c9f2df73c41ee46&vjs=3
# starting first 130 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=130
# 10
# https://www.indeed.com/rc/clk?jk=8d516efc15088fa5&fccid=185db914e9a93701&vjs=3
# https://www.indeed.com/rc/clk?jk=72f5c33a73032904&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=29e2fddcf2784347&fccid=21fd5e112e785caf&vjs=3
# https://www.indeed.com/rc/clk?jk=ac4a18fa4e51aadb&fccid=b544304db34cd3c6&vjs=3
# https://www.indeed.com/rc/clk?jk=7461e2740e17791b&fccid=f0595ebb13247329&vjs=3
# https://www.indeed.com/rc/clk?jk=f68dce1f8768c849&fccid=3436e62bd0052e4e&vjs=3
# https://www.indeed.com/rc/clk?jk=3f58f32646a42df0&fccid=4a58e879047f7cdb&vjs=3
# https://www.indeed.com/rc/clk?jk=df1c66f2c838171c&fccid=c6740ca0f8a588b9&vjs=3
# https://www.indeed.com/rc/clk?jk=137436e9c33ad7a5&fccid=f654deb7a558ae97&vjs=3
# https://www.indeed.com/rc/clk?jk=1b8ba1b3510a1608&fccid=de469d8ac5b42d90&vjs=3
# starting first 140 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=140
# 10
# https://www.indeed.com/rc/clk?jk=fd746ccc9251f231&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=ad1221f99c9efc15&fccid=9ad1ad400fd7beae&vjs=3
# https://www.indeed.com/rc/clk?jk=3760b9c770df02e7&fccid=1d2bef48e6fe1cfc&vjs=3
# https://www.indeed.com/rc/clk?jk=e7f5d24689e509d2&fccid=1850f361f1d8cab4&vjs=3
# https://www.indeed.com/rc/clk?jk=6c34e75a4fc7cf9a&fccid=5033463af3c58699&vjs=3
# https://www.indeed.com/rc/clk?jk=eb6336e5c0a9f86a&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=0726f608b0e8c027&fccid=760e068d52e579be&vjs=3
# https://www.indeed.com/rc/clk?jk=ebda34ad490cfb8f&fccid=9ff926b033a6c08c&vjs=3
# https://www.indeed.com/rc/clk?jk=e7f096160c8df047&fccid=2e1a7c477333437a&vjs=3
# https://www.indeed.com/rc/clk?jk=b9ca4a1d90a06ba4&fccid=db70737d31eac471&vjs=3
# starting first 150 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=150
# 8
# https://www.indeed.com/rc/clk?jk=d4e8231970c155bd&fccid=babf27961b57f30c&vjs=3
# https://www.indeed.com/rc/clk?jk=60528c557dbe0d2c&fccid=b4048be2884af072&vjs=3
# https://www.indeed.com/rc/clk?jk=9e9b6825dff44c1c&fccid=bcfb998b053bf6ab&vjs=3
# https://www.indeed.com/rc/clk?jk=16cfa605c014e67f&fccid=a1bf55e1391577a6&vjs=3
# https://www.indeed.com/rc/clk?jk=08304c6919c1b207&fccid=7cf620b1ef0018f8&vjs=3
# https://www.indeed.com/rc/clk?jk=6f27182424a21e53&fccid=04c4d5d87ff27beb&vjs=3
# https://www.indeed.com/rc/clk?jk=6eb9ed0592f68db6&fccid=db70737d31eac471&vjs=3
# https://www.indeed.com/rc/clk?jk=5ed77adac6a38977&fccid=10b2117760008d29&vjs=3
# starting first 160 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=160
# 9
# https://www.indeed.com/rc/clk?jk=08304c6919c1b207&fccid=7cf620b1ef0018f8&vjs=3
# https://www.indeed.com/rc/clk?jk=e50a24e520811c45&fccid=5feeab62533788e8&vjs=3
# https://www.indeed.com/rc/clk?jk=d0499a8add25f05c&fccid=0204e0b47df5d2bb&vjs=3
# https://www.indeed.com/rc/clk?jk=8a6428d0be72fa36&fccid=aeb15e43a6800b9d&vjs=3
# https://www.indeed.com/rc/clk?jk=e9e00fa2662fa9e3&fccid=727235324836b166&vjs=3
# https://www.indeed.com/rc/clk?jk=d4e8231970c155bd&fccid=babf27961b57f30c&vjs=3
# https://www.indeed.com/rc/clk?jk=ef2904700af4e27a&fccid=3c74eafe288fc8ca&vjs=3
# https://www.indeed.com/rc/clk?jk=10a4dd943e485454&fccid=720de09538df2ec5&vjs=3
# https://www.indeed.com/rc/clk?jk=a8fa02081f5dc02b&fccid=8e8916224c5a17da&vjs=3
# starting first 170 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=170
# 10
# https://www.indeed.com/rc/clk?jk=4d474ca62499333f&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=2e9af25cf16d26a5&fccid=4e73084b634b861d&vjs=3
# https://www.indeed.com/rc/clk?jk=da88376bd5e61ecd&fccid=d43486ebfbb771d1&vjs=3
# https://www.indeed.com/rc/clk?jk=1636faa0308fd08f&fccid=1577085fc2290983&vjs=3
# https://www.indeed.com/rc/clk?jk=91f3bc02127f6731&fccid=2b2c5ec57839c632&vjs=3
# https://www.indeed.com/rc/clk?jk=3f9328b15028d552&fccid=3a1edc2d763c4288&vjs=3
# https://www.indeed.com/rc/clk?jk=fc5b8c4c97720a45&fccid=cc35f9c14f8799a9&vjs=3
# https://www.indeed.com/rc/clk?jk=7e39bf980f3f3701&fccid=0ff890d2b9eda516&vjs=3
# https://www.indeed.com/rc/clk?jk=e9d91b77654ff467&fccid=8e5415c099aa948c&vjs=3
# https://www.indeed.com/rc/clk?jk=58abf555bc95a0fa&fccid=f770da67b3b51c62&vjs=3
# starting first 180 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=180
# 10
# https://www.indeed.com/rc/clk?jk=1c329336d3b7172e&fccid=74353ee3ba2a3337&vjs=3
# https://www.indeed.com/rc/clk?jk=674ee8e79b133d43&fccid=f17c99e507586c13&vjs=3
# https://www.indeed.com/rc/clk?jk=cb6f9f3b73e0a71d&fccid=d4f9c2eaf069523f&vjs=3
# https://www.indeed.com/rc/clk?jk=f020360fa2ff78c7&fccid=a7c9fbf66d7f3124&vjs=3
# https://www.indeed.com/rc/clk?jk=2696950c88d4665b&fccid=f23cfaf12528dbd0&vjs=3
# https://www.indeed.com/rc/clk?jk=ad1221f99c9efc15&fccid=9ad1ad400fd7beae&vjs=3
# https://www.indeed.com/rc/clk?jk=0323eba3f7bda356&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=3d4c752f8677fafc&fccid=c888c55c708fa7a8&vjs=3
# https://www.indeed.com/rc/clk?jk=6b57c35959dadbae&fccid=1faa299cbcd35ef2&vjs=3
# https://www.indeed.com/rc/clk?jk=884581bef36d0cbd&fccid=fa0ca3b638673d62&vjs=3
# starting first 190 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=190
# 10
# https://www.indeed.com/rc/clk?jk=5d4665f94e896653&fccid=5c542a53657c2a31&vjs=3
# https://www.indeed.com/rc/clk?jk=d5bd9c1f26890db2&fccid=39d9d123b68dadca&vjs=3
# https://www.indeed.com/rc/clk?jk=27fda9cd845fbb75&fccid=fd3e5b9fc7b91d7c&vjs=3
# https://www.indeed.com/rc/clk?jk=8cb89b28b63265f8&fccid=9b4e0bba38b405da&vjs=3
# https://www.indeed.com/rc/clk?jk=d936ecd0124761a7&fccid=62d1f6aaef9a271b&vjs=3
# https://www.indeed.com/rc/clk?jk=6d96d68ff583f0c5&fccid=3aaabf5c54e51db9&vjs=3
# https://www.indeed.com/rc/clk?jk=a4b0b1182c6ecf2e&fccid=5302b2b4db4fded5&vjs=3
# https://www.indeed.com/rc/clk?jk=e53947bbf2d9cbcb&fccid=4c069f49b73c7f31&vjs=3
# https://www.indeed.com/rc/clk?jk=3760b9c770df02e7&fccid=1d2bef48e6fe1cfc&vjs=3
# https://www.indeed.com/rc/clk?jk=16dec0f4c6c33128&fccid=c1099851e9794854&vjs=3
# starting first 200 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=200
# 10
# https://www.indeed.com/rc/clk?jk=f00030c7701d5368&fccid=d81bbfe26fad932d&vjs=3
# https://www.indeed.com/rc/clk?jk=ffff23a1d2adfd3a&fccid=794cd326a07c90fc&vjs=3
# https://www.indeed.com/rc/clk?jk=2a8cbe3d167657bc&fccid=8a3767c22b60ae1c&vjs=3
# https://www.indeed.com/rc/clk?jk=b77d67c7a6f69ca6&fccid=d4f9c2eaf069523f&vjs=3
# https://www.indeed.com/rc/clk?jk=14762009757e4bf3&fccid=9784ae78e9834539&vjs=3
# https://www.indeed.com/rc/clk?jk=74c598ac5da9cbb1&fccid=7077d7e88049c02a&vjs=3
# https://www.indeed.com/rc/clk?jk=4a61f4902569de2b&fccid=761110cb1eadb0d9&vjs=3
# https://www.indeed.com/rc/clk?jk=108c457285496a76&fccid=f34acbd24dd4fcb0&vjs=3
# https://www.indeed.com/rc/clk?jk=3323815d1096d3ce&fccid=53b041cb411b8ed4&vjs=3
# https://www.indeed.com/rc/clk?jk=d4465bc847ca8b4c&fccid=2ded1102b05cde6d&vjs=3
# starting first 210 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=210
# 10
# https://www.indeed.com/rc/clk?jk=b61b1ba0c3e9117f&fccid=bebf9775d7d3bca8&vjs=3
# https://www.indeed.com/rc/clk?jk=9f48930984e0d7d1&fccid=ed67770e4ccaf178&vjs=3
# https://www.indeed.com/rc/clk?jk=f013ec331e2188fb&fccid=7a3824693ee1074b&vjs=3
# https://www.indeed.com/rc/clk?jk=009661d5331a1928&fccid=ee32437d8dec00bd&vjs=3
# https://www.indeed.com/rc/clk?jk=d4069bc94acc6ada&fccid=74fbc768a4e5bece&vjs=3
# https://www.indeed.com/rc/clk?jk=15d433e99e063a5a&fccid=f03f4be28dbdabc8&vjs=3
# https://www.indeed.com/rc/clk?jk=55d47f28d22046a6&fccid=a3bcc3a125bee804&vjs=3
# https://www.indeed.com/rc/clk?jk=adb53d5dc431289b&fccid=64e028df9b3fd2c4&vjs=3
# https://www.indeed.com/rc/clk?jk=76375d7555620091&fccid=aeb15e43a6800b9d&vjs=3
# https://www.indeed.com/rc/clk?jk=e50a24e520811c45&fccid=5feeab62533788e8&vjs=3
# starting first 220 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=220
# 10
# https://www.indeed.com/rc/clk?jk=0726f608b0e8c027&fccid=760e068d52e579be&vjs=3
# https://www.indeed.com/rc/clk?jk=68ec9027aa95b703&fccid=cb8355041fe4a920&vjs=3
# https://www.indeed.com/rc/clk?jk=de5cb8885d72d72c&fccid=5b2f9eaa91cb3370&vjs=3
# https://www.indeed.com/rc/clk?jk=29fde2648d552f82&fccid=8a3de18d48c837d2&vjs=3
# https://www.indeed.com/rc/clk?jk=f7704e34598e8733&fccid=a8bb679ce7a3eb45&vjs=3
# https://www.indeed.com/rc/clk?jk=a44b1e81a4fcea3f&fccid=1b50fcfb150b1b48&vjs=3
# https://www.indeed.com/rc/clk?jk=4b9f09ea2d3a9389&fccid=c5e82b682b93e4db&vjs=3
# https://www.indeed.com/rc/clk?jk=fe40a430ffe93792&fccid=dd73ad6992d82d48&vjs=3
# https://www.indeed.com/rc/clk?jk=b8a3c019c44a1564&fccid=0dd0f2dc4ecc3d85&vjs=3
# https://www.indeed.com/rc/clk?jk=025026ffa4313fb4&fccid=617d7f961cfcf54a&vjs=3
# starting first 230 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=230
# 15
# https://www.indeed.com/rc/clk?jk=1ad3c3b570ead53d&fccid=cbaaf6d9b36859d8&vjs=3
# https://www.indeed.com/rc/clk?jk=67adf6c115a96042&fccid=fa691bd7d26474a1&vjs=3
# https://www.indeed.com/rc/clk?jk=a46f46522032ead8&fccid=ea25315ee9da22e5&vjs=3
# https://www.indeed.com/rc/clk?jk=c19602fa71f2ab12&fccid=dfc44f3b8c44a6db&vjs=3
# https://www.indeed.com/rc/clk?jk=a89408fbe84c934e&fccid=c629e32155ebd42c&vjs=3
# https://www.indeed.com/rc/clk?jk=a34cad2a24e05035&fccid=d7c744248a9e6859&vjs=3
# https://www.indeed.com/rc/clk?jk=3abdf97b1679e92d&fccid=bc5afa013c617a43&vjs=3
# https://www.indeed.com/rc/clk?jk=05646157296007e2&fccid=113517153f849886&vjs=3
# https://www.indeed.com/rc/clk?jk=ad09186f43c5564b&fccid=d46e0b83498fa11f&vjs=3
# https://www.indeed.com/rc/clk?jk=82af4a12a7edbe46&fccid=7fc6d3992188a532&vjs=3
# https://www.indeed.com/rc/clk?jk=9bbcd4849529d9f5&fccid=265f51e5896cd7e4&vjs=3
# https://www.indeed.com/rc/clk?jk=49999ffe7f60cbb9&fccid=e9f1decdeceb0168&vjs=3
# https://www.indeed.com/rc/clk?jk=f5ed8e3ecde0c424&fccid=7099c252b3f1ca25&vjs=3
# https://www.indeed.com/rc/clk?jk=a6af6e15c68a7e7d&fccid=aef928e89977f7f0&vjs=3
# https://www.indeed.com/rc/clk?jk=9d7a4e77ccc04f97&fccid=837edc3ec6c2367e&vjs=3
# starting first 240 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=240
# 10
# https://www.indeed.com/rc/clk?jk=228a00c6386b6799&fccid=6204ad93e6d7930f&vjs=3
# https://www.indeed.com/rc/clk?jk=fa85fb93709b0184&fccid=76d3630986f5b206&vjs=3
# https://www.indeed.com/rc/clk?jk=feb58b47ffc13dab&fccid=80f650ebe16034d3&vjs=3
# https://www.indeed.com/rc/clk?jk=137436e9c33ad7a5&fccid=f654deb7a558ae97&vjs=3
# https://www.indeed.com/rc/clk?jk=37bf1da314a6449c&fccid=356996d56a985620&vjs=3
# https://www.indeed.com/rc/clk?jk=7c8c78ca692194df&fccid=fd02f21940de3731&vjs=3
# https://www.indeed.com/rc/clk?jk=1e3d9fa564f232ee&fccid=a1f095f24610779f&vjs=3
# https://www.indeed.com/rc/clk?jk=4bbda10390bdb2e2&fccid=164d435e34f87c4e&vjs=3
# https://www.indeed.com/rc/clk?jk=a4b0b1182c6ecf2e&fccid=5302b2b4db4fded5&vjs=3
# https://www.indeed.com/rc/clk?jk=9a8763b437457c02&fccid=bcaf9dcbb1769b32&vjs=3
# starting first 250 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=250
# 10
# https://www.indeed.com/rc/clk?jk=87715830056e3aee&fccid=f74a75b45328cae2&vjs=3
# https://www.indeed.com/rc/clk?jk=f7704e34598e8733&fccid=a8bb679ce7a3eb45&vjs=3
# https://www.indeed.com/rc/clk?jk=369ca4801f9df574&fccid=cc35f9c14f8799a9&vjs=3
# https://www.indeed.com/rc/clk?jk=9506e5358c00fe85&fccid=217bc2676cf508aa&vjs=3
# https://www.indeed.com/rc/clk?jk=a1cd7c5d6e24488e&fccid=2150e83695978641&vjs=3
# https://www.indeed.com/rc/clk?jk=68ec9027aa95b703&fccid=cb8355041fe4a920&vjs=3
# https://www.indeed.com/rc/clk?jk=c0b0fd1f47e4db8c&fccid=c5c4cbbef8d07871&vjs=3
# https://www.indeed.com/rc/clk?jk=0fa1525d3a42ab90&fccid=5f4734be3d0d8354&vjs=3
# https://www.indeed.com/rc/clk?jk=55d47f28d22046a6&fccid=a3bcc3a125bee804&vjs=3
# https://www.indeed.com/rc/clk?jk=fe40a430ffe93792&fccid=dd73ad6992d82d48&vjs=3
# starting first 260 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=260
# 15
# https://www.indeed.com/rc/clk?jk=2d0db46d70260dc6&fccid=eeaf6e4fd346d590&vjs=3
# https://www.indeed.com/rc/clk?jk=54dd8869dbe7bd7a&fccid=519cd80cc4a237e4&vjs=3
# https://www.indeed.com/rc/clk?jk=83f30f082a5cedbd&fccid=017f60f60315e4b4&vjs=3
# https://www.indeed.com/rc/clk?jk=4c3895e736325e82&fccid=6a073cd614507165&vjs=3
# https://www.indeed.com/rc/clk?jk=44a43a7d4d8d3da8&fccid=615439ce5f0611a4&vjs=3
# https://www.indeed.com/rc/clk?jk=59bf368092f2ba32&fccid=c4b7f809097a101b&vjs=3
# https://www.indeed.com/rc/clk?jk=756d5075d4e5b05f&fccid=8fefdd19cc706a7c&vjs=3
# https://www.indeed.com/rc/clk?jk=108c457285496a76&fccid=f34acbd24dd4fcb0&vjs=3
# https://www.indeed.com/rc/clk?jk=bbb0c72695e4c59c&fccid=237908de095b6446&vjs=3
# https://www.indeed.com/rc/clk?jk=90d445e175e71894&fccid=0b3490f8005058ec&vjs=3
# https://www.indeed.com/rc/clk?jk=2348d28dc213efd9&fccid=d5223a4cbfaf1ce6&vjs=3
# https://www.indeed.com/rc/clk?jk=915a04b00fd96ae8&fccid=451a594b449eb102&vjs=3
# https://www.indeed.com/rc/clk?jk=3ce86ed0a07b2c2b&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=29e164b4daa98f93&fccid=ecad17dfe9510a8d&vjs=3
# https://www.indeed.com/rc/clk?jk=77085abc2a0ec4ca&fccid=9784ae78e9834539&vjs=3
# starting first 270 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=270
# 10
# https://www.indeed.com/rc/clk?jk=cd123641c37fe387&fccid=2e891761606958f0&vjs=3
# https://www.indeed.com/rc/clk?jk=462be038fc1cbed0&fccid=cc0919f84b5fb6ac&vjs=3
# https://www.indeed.com/rc/clk?jk=3e4e8bb9940f9691&fccid=dbe97974d004cd2e&vjs=3
# https://www.indeed.com/rc/clk?jk=dc76fb7e2b99d56a&fccid=e87c07079f6e369f&vjs=3
# https://www.indeed.com/rc/clk?jk=1b8d347b692ecd9f&fccid=1f43d73c149f08bd&vjs=3
# https://www.indeed.com/rc/clk?jk=539ec7d5d0eb36a9&fccid=bd976cc171c690e0&vjs=3
# https://www.indeed.com/rc/clk?jk=12dbf9a393bfcf7f&fccid=4ba35c44ff727b61&vjs=3
# https://www.indeed.com/rc/clk?jk=8c6bad588576f113&fccid=a5b4499d9e91a5c6&vjs=3
# https://www.indeed.com/rc/clk?jk=5a0b556b09afcdb2&fccid=f085b82fff829085&vjs=3
# https://www.indeed.com/rc/clk?jk=bc944e4f1901985a&fccid=21df030fae150acc&vjs=3
# starting first 280 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=280
# 9
# https://www.indeed.com/rc/clk?jk=d20d5386e729ea62&fccid=6262eae176df0db9&vjs=3
# https://www.indeed.com/rc/clk?jk=feb58b47ffc13dab&fccid=80f650ebe16034d3&vjs=3
# https://www.indeed.com/rc/clk?jk=9a0b6e44be850e8a&fccid=104dac531ec80260&vjs=3
# https://www.indeed.com/rc/clk?jk=dc76fb7e2b99d56a&fccid=e87c07079f6e369f&vjs=3
# https://www.indeed.com/rc/clk?jk=1993bee97ad01b88&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=a4b0b1182c6ecf2e&fccid=5302b2b4db4fded5&vjs=3
# https://www.indeed.com/rc/clk?jk=eed379c0ad28456b&fccid=caed318a9335aac0&vjs=3
# https://www.indeed.com/rc/clk?jk=f31213ed278f7be2&fccid=3e263cf17592f3f5&vjs=3
# https://www.indeed.com/rc/clk?jk=2a8cbe3d167657bc&fccid=8a3767c22b60ae1c&vjs=3
# starting first 290 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=290
# 15
# https://www.indeed.com/rc/clk?jk=5a36da9bbd2c8dfb&fccid=c0f8fe90d3cd91fa&vjs=3
# https://www.indeed.com/rc/clk?jk=2f3ac166a8625731&fccid=f1374be6a45f4b8a&vjs=3
# https://www.indeed.com/rc/clk?jk=37bf1da314a6449c&fccid=356996d56a985620&vjs=3
# https://www.indeed.com/rc/clk?jk=fe07a6c86d3e9e52&fccid=388ffa8e9601f976&vjs=3
# https://www.indeed.com/rc/clk?jk=ecc60f2cb1d91fd2&fccid=f770da67b3b51c62&vjs=3
# https://www.indeed.com/rc/clk?jk=601a1019f036a683&fccid=3bb96a69f06a6ccc&vjs=3
# https://www.indeed.com/rc/clk?jk=c3367eec44102176&fccid=ab120b4b200bc8db&vjs=3
# https://www.indeed.com/rc/clk?jk=f9427550d1a2c43e&fccid=7e039861f9e93845&vjs=3
# https://www.indeed.com/rc/clk?jk=db2859cbf88343d6&fccid=73e7cfa1796d463f&vjs=3
# https://www.indeed.com/rc/clk?jk=147dbd1a67c4e6e1&fccid=2ded1102b05cde6d&vjs=3
# https://www.indeed.com/rc/clk?jk=3cd4c85b635c652f&fccid=462555dec0279094&vjs=3
# https://www.indeed.com/rc/clk?jk=3b19503738f7d93f&fccid=c1099851e9794854&vjs=3
# https://www.indeed.com/rc/clk?jk=6d242cb1ef23477b&fccid=6c60402abd737dc9&vjs=3
# https://www.indeed.com/rc/clk?jk=ab1e1544681127f8&fccid=565792134b40dcb5&vjs=3
# https://www.indeed.com/rc/clk?jk=afdd124510c90004&fccid=c8fc142c28286059&vjs=3
# starting first 300 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=300
# 10
# https://www.indeed.com/rc/clk?jk=38da2ce892d4c69f&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=996c13e727f894ed&fccid=6595db4e00c1e70f&vjs=3
# https://www.indeed.com/rc/clk?jk=f6bfcea28a468d53&fccid=883c40c39cd48786&vjs=3
# https://www.indeed.com/rc/clk?jk=eb6336e5c0a9f86a&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=36f9998ce024d56b&fccid=de71a49b535e21cb&vjs=3
# https://www.indeed.com/rc/clk?jk=107cf3662282f46e&fccid=3394fcad38da6a2d&vjs=3
# https://www.indeed.com/rc/clk?jk=57b29ac714404b27&fccid=56c25448bab54e90&vjs=3
# https://www.indeed.com/rc/clk?jk=659b8227af7948c3&fccid=c1099851e9794854&vjs=3
# https://www.indeed.com/rc/clk?jk=4f0516523bbebf69&fccid=8b9bafd9d608c198&vjs=3
# https://www.indeed.com/rc/clk?jk=694f1d85ed6eb5f3&fccid=a7c5036618407010&vjs=3
# starting first 310 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=310
# 10
# https://www.indeed.com/rc/clk?jk=895198afc6b8f935&fccid=89c8ac09f8659f98&vjs=3
# https://www.indeed.com/rc/clk?jk=d3fc8ae2ee583fec&fccid=403c563aa0968a06&vjs=3
# https://www.indeed.com/rc/clk?jk=b3f675b7de4e0418&fccid=caaf1a960095c607&vjs=3
# https://www.indeed.com/rc/clk?jk=0c1592a1acb4f933&fccid=81ddb723255b4ba2&vjs=3
# https://www.indeed.com/rc/clk?jk=1c329336d3b7172e&fccid=74353ee3ba2a3337&vjs=3
# https://www.indeed.com/rc/clk?jk=7598738a474017e8&fccid=3bc096a5907f15dd&vjs=3
# https://www.indeed.com/rc/clk?jk=72e40feee45f32db&fccid=7e039861f9e93845&vjs=3
# https://www.indeed.com/rc/clk?jk=02719aaec5f0cdc9&fccid=5b2f9eaa91cb3370&vjs=3
# https://www.indeed.com/rc/clk?jk=49a226a59d382e8d&fccid=d25525f95db539b9&vjs=3
# https://www.indeed.com/rc/clk?jk=57b29ac714404b27&fccid=56c25448bab54e90&vjs=3
# starting first 320 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=320
# 10
# https://www.indeed.com/rc/clk?jk=420628d026acc5c0&fccid=448951d0ddf03e0c&vjs=3
# https://www.indeed.com/rc/clk?jk=e99263667e55f44b&fccid=290a4498a64fc044&vjs=3
# https://www.indeed.com/rc/clk?jk=ada27853d9d1058a&fccid=5feeab62533788e8&vjs=3
# https://www.indeed.com/rc/clk?jk=8962afff39919742&fccid=0020d0f25b7dca49&vjs=3
# https://www.indeed.com/rc/clk?jk=4b9f09ea2d3a9389&fccid=c5e82b682b93e4db&vjs=3
# https://www.indeed.com/rc/clk?jk=8a14ff83a860d922&fccid=4abe952c267192fa&vjs=3
# https://www.indeed.com/rc/clk?jk=387a55d39210396a&fccid=1a0e250dea25baf5&vjs=3
# https://www.indeed.com/rc/clk?jk=e56daa6e5a3a3223&fccid=3d0f7ba22a49432f&vjs=3
# https://www.indeed.com/rc/clk?jk=8c6bad588576f113&fccid=a5b4499d9e91a5c6&vjs=3
# https://www.indeed.com/rc/clk?jk=e75d93e1be52298f&fccid=b8f9a4a59febf2b1&vjs=3
# starting first 330 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=330
# 10
# https://www.indeed.com/rc/clk?jk=b096e45c6ae69b9f&fccid=d4f9c2eaf069523f&vjs=3
# https://www.indeed.com/rc/clk?jk=ee36643adaf95389&fccid=3b86d9aa300662f9&vjs=3
# https://www.indeed.com/rc/clk?jk=03f1b1eca877883a&fccid=3c0568dd833fc7ab&vjs=3
# https://www.indeed.com/rc/clk?jk=5a36da9bbd2c8dfb&fccid=c0f8fe90d3cd91fa&vjs=3
# https://www.indeed.com/rc/clk?jk=3f290273ab7e1516&fccid=3eb395872a6dc087&vjs=3
# https://www.indeed.com/rc/clk?jk=f6353b8d8f2ae968&fccid=8630438014dc7c52&vjs=3
# https://www.indeed.com/rc/clk?jk=ccabacae6c2a8801&fccid=ed5ca8514f115c48&vjs=3
# https://www.indeed.com/rc/clk?jk=22be3637f49f1a8a&fccid=0fbf324c877976f6&vjs=3
# https://www.indeed.com/rc/clk?jk=68ec9027aa95b703&fccid=cb8355041fe4a920&vjs=3
# https://www.indeed.com/rc/clk?jk=2c5cb2969c16d2ca&fccid=b6b16fcce9acaef1&vjs=3
# starting first 340 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=340
# 10
# https://www.indeed.com/rc/clk?jk=6c78dd70dff2287e&fccid=f884b5ea8b764a1a&vjs=3
# https://www.indeed.com/rc/clk?jk=a46f46522032ead8&fccid=ea25315ee9da22e5&vjs=3
# https://www.indeed.com/rc/clk?jk=f7c2f7196ea19bac&fccid=847fa4d5cb464f5a&vjs=3
# https://www.indeed.com/rc/clk?jk=de5cb8885d72d72c&fccid=5b2f9eaa91cb3370&vjs=3
# https://www.indeed.com/rc/clk?jk=96bdf4f8ce26dc76&fccid=8b9bafd9d608c198&vjs=3
# https://www.indeed.com/rc/clk?jk=c5ee5539f7da72cc&fccid=9a199e21f9f95369&vjs=3
# https://www.indeed.com/rc/clk?jk=771ec6885c33169f&fccid=00ae4e776f21bc2f&vjs=3
# https://www.indeed.com/rc/clk?jk=3cd4c85b635c652f&fccid=462555dec0279094&vjs=3
# https://www.indeed.com/rc/clk?jk=fe07a6c86d3e9e52&fccid=388ffa8e9601f976&vjs=3
# https://www.indeed.com/rc/clk?jk=9f48930984e0d7d1&fccid=ed67770e4ccaf178&vjs=3
# starting first 350 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=350
# 10
# https://www.indeed.com/rc/clk?jk=14815c19cc272266&fccid=854b6265d5210a19&vjs=3
# https://www.indeed.com/rc/clk?jk=82af4a12a7edbe46&fccid=7fc6d3992188a532&vjs=3
# https://www.indeed.com/rc/clk?jk=d6f221b4407765fe&fccid=6b7a1dfe07e7f037&vjs=3
# https://www.indeed.com/rc/clk?jk=cedec3ad4f22493d&fccid=3c9f2df73c41ee46&vjs=3
# https://www.indeed.com/rc/clk?jk=80dcbc9f4d554429&fccid=feaabf8e6a699d3c&vjs=3
# https://www.indeed.com/rc/clk?jk=d4893a9b0eb8eb34&fccid=942d7466867b4590&vjs=3
# https://www.indeed.com/rc/clk?jk=e863f7688e495db2&fccid=5ece327da33e0274&vjs=3
# https://www.indeed.com/rc/clk?jk=2348d28dc213efd9&fccid=d5223a4cbfaf1ce6&vjs=3
# https://www.indeed.com/rc/clk?jk=c9187ac3630ff89b&fccid=11619ce0d3c2c733&vjs=3
# https://www.indeed.com/rc/clk?jk=77a10c967512aa7c&fccid=45056d760b7d9d86&vjs=3
# starting first 360 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=360
# 10
# https://www.indeed.com/rc/clk?jk=499d5ae010cca490&fccid=b248c1298917ecc7&vjs=3
# https://www.indeed.com/rc/clk?jk=6ed3bbf2d1095475&fccid=bcddd4edac344549&vjs=3
# https://www.indeed.com/rc/clk?jk=cdc6971d57b63fd0&fccid=ec30d82962c8b13b&vjs=3
# https://www.indeed.com/rc/clk?jk=d4191b5ebb81700a&fccid=8de1633f2f8eae1d&vjs=3
# https://www.indeed.com/rc/clk?jk=b4e218a1a7e05d96&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=a46f46522032ead8&fccid=ea25315ee9da22e5&vjs=3
# https://www.indeed.com/rc/clk?jk=dcc0260f3a08a4c8&fccid=91bbd9dc41595b3e&vjs=3
# https://www.indeed.com/rc/clk?jk=f09a6d6e7cf24434&fccid=d3d3520998346837&vjs=3
# https://www.indeed.com/rc/clk?jk=644c8573d9573b15&fccid=f82779f9f5d1aa9b&vjs=3
# https://www.indeed.com/rc/clk?jk=3483ac001da233ed&fccid=e571ceda55e25d27&vjs=3
# starting first 370 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=370
# 10
# https://www.indeed.com/rc/clk?jk=78edb3c22959e53e&fccid=fb556c90cb9bdb1a&vjs=3
# https://www.indeed.com/rc/clk?jk=f99c4e9340a045dd&fccid=8e1b3eba64c2138d&vjs=3
# https://www.indeed.com/rc/clk?jk=2e9af25cf16d26a5&fccid=4e73084b634b861d&vjs=3
# https://www.indeed.com/rc/clk?jk=900756df71faa905&fccid=214358c3b9aaf27e&vjs=3
# https://www.indeed.com/rc/clk?jk=15d433e99e063a5a&fccid=f03f4be28dbdabc8&vjs=3
# https://www.indeed.com/rc/clk?jk=4a852dcebc00e69a&fccid=22d5413651f4514c&vjs=3
# https://www.indeed.com/rc/clk?jk=3ad6571b80b8d9a3&fccid=b000a8bfa0ce3df8&vjs=3
# https://www.indeed.com/rc/clk?jk=2a2234ca7d12033b&fccid=c007936ceb766fe5&vjs=3
# https://www.indeed.com/rc/clk?jk=bc7705c36a299b57&fccid=c2808fe7c60a5f9a&vjs=3
# https://www.indeed.com/rc/clk?jk=83f30f082a5cedbd&fccid=017f60f60315e4b4&vjs=3
# starting first 380 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=380
# 10
# https://www.indeed.com/rc/clk?jk=8a9ac525aa6fbca2&fccid=0261464f5914d039&vjs=3
# https://www.indeed.com/rc/clk?jk=d1b45d6db178664f&fccid=1e0f17831c17f620&vjs=3
# https://www.indeed.com/rc/clk?jk=499d5ae010cca490&fccid=b248c1298917ecc7&vjs=3
# https://www.indeed.com/rc/clk?jk=7e39bf980f3f3701&fccid=0ff890d2b9eda516&vjs=3
# https://www.indeed.com/rc/clk?jk=104c47d6d3ca2958&fccid=a24a8c8e261b68e0&vjs=3
# https://www.indeed.com/rc/clk?jk=8800e99405c1ad93&fccid=d2310af9b3bb8585&vjs=3
# https://www.indeed.com/rc/clk?jk=d028dba91d748754&fccid=86b3fd3a4f34e6d2&vjs=3
# https://www.indeed.com/rc/clk?jk=8577b0300f603b76&fccid=fb556c90cb9bdb1a&vjs=3
# https://www.indeed.com/rc/clk?jk=12508958e2514320&fccid=72b6c36250909407&vjs=3
# https://www.indeed.com/rc/clk?jk=8aa15e29fef85c9c&fccid=632d2a253ffbf4f9&vjs=3
# starting first 390 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=390
# 10
# https://www.indeed.com/rc/clk?jk=2e297ea4bb07f2e4&fccid=7df2a06cf9f1c98b&vjs=3
# https://www.indeed.com/rc/clk?jk=d028dba91d748754&fccid=86b3fd3a4f34e6d2&vjs=3
# https://www.indeed.com/rc/clk?jk=4c3895e736325e82&fccid=6a073cd614507165&vjs=3
# https://www.indeed.com/rc/clk?jk=54dd8869dbe7bd7a&fccid=519cd80cc4a237e4&vjs=3
# https://www.indeed.com/rc/clk?jk=83f30f082a5cedbd&fccid=017f60f60315e4b4&vjs=3
# https://www.indeed.com/rc/clk?jk=44a43a7d4d8d3da8&fccid=615439ce5f0611a4&vjs=3
# https://www.indeed.com/rc/clk?jk=59bf368092f2ba32&fccid=c4b7f809097a101b&vjs=3
# https://www.indeed.com/rc/clk?jk=756d5075d4e5b05f&fccid=8fefdd19cc706a7c&vjs=3
# https://www.indeed.com/rc/clk?jk=108c457285496a76&fccid=f34acbd24dd4fcb0&vjs=3
# https://www.indeed.com/rc/clk?jk=bbb0c72695e4c59c&fccid=237908de095b6446&vjs=3
# starting first 400 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=400
# 10
# https://www.indeed.com/rc/clk?jk=90d445e175e71894&fccid=0b3490f8005058ec&vjs=3
# https://www.indeed.com/rc/clk?jk=2348d28dc213efd9&fccid=d5223a4cbfaf1ce6&vjs=3
# https://www.indeed.com/rc/clk?jk=915a04b00fd96ae8&fccid=451a594b449eb102&vjs=3
# https://www.indeed.com/rc/clk?jk=3ce86ed0a07b2c2b&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=29e164b4daa98f93&fccid=ecad17dfe9510a8d&vjs=3
# https://www.indeed.com/rc/clk?jk=ee2f1d072116faa7&fccid=ae5bfc395c530fbc&vjs=3
# https://www.indeed.com/rc/clk?jk=13ce235fa063295c&fccid=d25525f95db539b9&vjs=3
# https://www.indeed.com/rc/clk?jk=8a14ff83a860d922&fccid=4abe952c267192fa&vjs=3
# https://www.indeed.com/rc/clk?jk=f2767c0451e89178&fccid=6945a49c8dcc096e&vjs=3
# https://www.indeed.com/rc/clk?jk=8367a32b681c1154&fccid=43b36a11cda569b6&vjs=3
# starting first 410 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=410
# 15
# https://www.indeed.com/rc/clk?jk=c4343ded6c966ce7&fccid=3c0568dd833fc7ab&vjs=3
# https://www.indeed.com/rc/clk?jk=696ae13533536801&fccid=abf3c1ca1d06e469&vjs=3
# https://www.indeed.com/rc/clk?jk=539843aa92aaf8ce&fccid=a23e5e2f20b1aac4&vjs=3
# https://www.indeed.com/rc/clk?jk=e22d2ad87972a905&fccid=3a1edc2d763c4288&vjs=3
# https://www.indeed.com/rc/clk?jk=66645c35035646b6&fccid=7affa64765ffaf8f&vjs=3
# https://www.indeed.com/rc/clk?jk=06fc9f4909258517&fccid=34c446722f3cf576&vjs=3
# https://www.indeed.com/rc/clk?jk=c673acb5256fd85b&fccid=822bc5d9a49270ea&vjs=3
# https://www.indeed.com/rc/clk?jk=17d280b27ec3edf7&fccid=51cb746ff520ae73&vjs=3
# https://www.indeed.com/rc/clk?jk=2be72618c62dcacd&fccid=f58a1323585cadb0&vjs=3
# https://www.indeed.com/rc/clk?jk=b269d6c0c2478781&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=a3b31c7a153201b5&fccid=b66c01ddfaeadf60&vjs=3
# https://www.indeed.com/rc/clk?jk=c5b39d88d5f5ccf4&fccid=1b407becb7779fe4&vjs=3
# https://www.indeed.com/rc/clk?jk=ae6fd0507667d081&fccid=2dda8667d8de78d8&vjs=3
# https://www.indeed.com/rc/clk?jk=82d63244671107ad&fccid=e4af9ca5b6d3a604&vjs=3
# https://www.indeed.com/rc/clk?jk=7c387d42dad53f16&fccid=194eef4c168b8cc5&vjs=3
# starting first 420 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=420
# 10
# https://www.indeed.com/rc/clk?jk=958145d502def461&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=1098b9f5641b5a63&fccid=9dc947a49d640d59&vjs=3
# https://www.indeed.com/rc/clk?jk=be733496ce7b9cf8&fccid=afbf8c270610a38a&vjs=3
# https://www.indeed.com/rc/clk?jk=ada27853d9d1058a&fccid=5feeab62533788e8&vjs=3
# https://www.indeed.com/rc/clk?jk=e8c87405999c6070&fccid=77fef78ac719a2e2&vjs=3
# https://www.indeed.com/rc/clk?jk=340a8b65a73d689e&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=06ee5ffa770c0ea4&fccid=ee24dd71b9bf38cc&vjs=3
# https://www.indeed.com/rc/clk?jk=b23739613a0fbc4b&fccid=ab0ef6192557a06f&vjs=3
# https://www.indeed.com/rc/clk?jk=7cacc695f40b8481&fccid=73790d638c6583f2&vjs=3
# https://www.indeed.com/rc/clk?jk=a966dc631235030d&fccid=1639254ea84748b5&vjs=3
# starting first 430 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=430
# 9
# https://www.indeed.com/rc/clk?jk=ecdc39b52216611b&fccid=6f24c6869e609400&vjs=3
# https://www.indeed.com/rc/clk?jk=915a04b00fd96ae8&fccid=451a594b449eb102&vjs=3
# https://www.indeed.com/rc/clk?jk=cdc6971d57b63fd0&fccid=ec30d82962c8b13b&vjs=3
# https://www.indeed.com/rc/clk?jk=2e050f0f46a26175&fccid=f0f1f75e7a34ab34&vjs=3
# https://www.indeed.com/rc/clk?jk=2e297ea4bb07f2e4&fccid=7df2a06cf9f1c98b&vjs=3
# https://www.indeed.com/rc/clk?jk=a46f46522032ead8&fccid=ea25315ee9da22e5&vjs=3
# https://www.indeed.com/rc/clk?jk=340a8b65a73d689e&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=e6e7b13b23d41280&fccid=4f470a66747714f9&vjs=3
# https://www.indeed.com/rc/clk?jk=bc7705c36a299b57&fccid=c2808fe7c60a5f9a&vjs=3
# starting first 440 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=440
# 10
# https://www.indeed.com/rc/clk?jk=5e5aac899215bcd9&fccid=3bb96a69f06a6ccc&vjs=3
# https://www.indeed.com/rc/clk?jk=3483ac001da233ed&fccid=e571ceda55e25d27&vjs=3
# https://www.indeed.com/rc/clk?jk=29e164b4daa98f93&fccid=ecad17dfe9510a8d&vjs=3
# https://www.indeed.com/rc/clk?jk=e4257048089a0f56&fccid=8765a4045377753a&vjs=3
# https://www.indeed.com/rc/clk?jk=c8cd3231c663e4a0&fccid=b8fdf400786b78b1&vjs=3
# https://www.indeed.com/rc/clk?jk=6d242cb1ef23477b&fccid=6c60402abd737dc9&vjs=3
# https://www.indeed.com/rc/clk?jk=fe07a6c86d3e9e52&fccid=388ffa8e9601f976&vjs=3
# https://www.indeed.com/rc/clk?jk=5f2008986b0bc356&fccid=42f139d35fc5ecb9&vjs=3
# https://www.indeed.com/rc/clk?jk=a1929686d1c7a474&fccid=b74955bbcc3f8c96&vjs=3
# https://www.indeed.com/rc/clk?jk=22aef441ac8040b7&fccid=763021c8881c79ad&vjs=3
# starting first 450 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=450
# 10
# https://www.indeed.com/rc/clk?jk=22d93c82e655c0c6&fccid=dd879caa632659ef&vjs=3
# https://www.indeed.com/rc/clk?jk=c595981e1f1dbb39&fccid=25d2167a5148eee2&vjs=3
# https://www.indeed.com/rc/clk?jk=1510e716a05dabce&fccid=f8ffb6ca1136aaff&vjs=3
# https://www.indeed.com/rc/clk?jk=3ad70775388f63fd&fccid=200a825acadb9338&vjs=3
# https://www.indeed.com/rc/clk?jk=ce0eb1898971518b&fccid=a7d9ad7a122f9785&vjs=3
# https://www.indeed.com/rc/clk?jk=6e5d44d73298abf6&fccid=ec4d3f88affe63ec&vjs=3
# https://www.indeed.com/rc/clk?jk=a89408fbe84c934e&fccid=c629e32155ebd42c&vjs=3
# https://www.indeed.com/rc/clk?jk=d43dd6d34859059a&fccid=f031515c17652ecd&vjs=3
# https://www.indeed.com/rc/clk?jk=efe8ad44c6232051&fccid=6b7a1dfe07e7f037&vjs=3
# https://www.indeed.com/rc/clk?jk=e3c5cdfd47480d95&fccid=50b6ec04dddc3e05&vjs=3
# starting first 460 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=460
# 10
# https://www.indeed.com/rc/clk?jk=d8bb99b62126fdd2&fccid=7e2f25c82f274980&vjs=3
# https://www.indeed.com/rc/clk?jk=e017645bb51a88a0&fccid=e2e8cfb17a406cbf&vjs=3
# https://www.indeed.com/rc/clk?jk=ad6fe0dcb36035a3&fccid=761110cb1eadb0d9&vjs=3
# https://www.indeed.com/rc/clk?jk=99d25708aac3436c&fccid=8c49e99f20f89e48&vjs=3
# https://www.indeed.com/rc/clk?jk=5877ff5b25bfee9c&fccid=dd616958bd9ddc12&vjs=3
# https://www.indeed.com/rc/clk?jk=8fac3958aa1d5a47&fccid=a575b7c5c50b587a&vjs=3
# https://www.indeed.com/rc/clk?jk=859f8cd20ab58e8e&fccid=69721041e85636d8&vjs=3
# https://www.indeed.com/rc/clk?jk=ed048fc50087884c&fccid=6b7a1dfe07e7f037&vjs=3
# https://www.indeed.com/rc/clk?jk=34f7d9cae3ab186b&fccid=b0d9d419dcb47ab5&vjs=3
# https://www.indeed.com/rc/clk?jk=12508958e2514320&fccid=72b6c36250909407&vjs=3
# starting first 470 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=470
# 10
# https://www.indeed.com/rc/clk?jk=a78c8a2d42ce3b51&fccid=8902ec4b71211d48&vjs=3
# https://www.indeed.com/rc/clk?jk=79916d4feefe58cd&fccid=15c26b2f7c7309c1&vjs=3
# https://www.indeed.com/rc/clk?jk=c4fe85e0f4b19c4a&fccid=5f4734be3d0d8354&vjs=3
# https://www.indeed.com/rc/clk?jk=897a9bc2d2d22379&fccid=84e6170ed8a9b47b&vjs=3
# https://www.indeed.com/rc/clk?jk=05646157296007e2&fccid=113517153f849886&vjs=3
# https://www.indeed.com/rc/clk?jk=694f1d85ed6eb5f3&fccid=a7c5036618407010&vjs=3
# https://www.indeed.com/rc/clk?jk=62c9c409864b941e&fccid=adbe87789e71ebaf&vjs=3
# https://www.indeed.com/rc/clk?jk=a34cad2a24e05035&fccid=d7c744248a9e6859&vjs=3
# https://www.indeed.com/rc/clk?jk=d4069bc94acc6ada&fccid=74fbc768a4e5bece&vjs=3
# https://www.indeed.com/rc/clk?jk=ff0ebfe3ae25dfc0&fccid=eb72af02edf9901b&vjs=3
# starting first 480 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=480
# 10
# https://www.indeed.com/rc/clk?jk=d9ce7207cce5fb81&fccid=49a5c211e884fc9a&vjs=3
# https://www.indeed.com/rc/clk?jk=f00030c7701d5368&fccid=d81bbfe26fad932d&vjs=3
# https://www.indeed.com/rc/clk?jk=c3367eec44102176&fccid=ab120b4b200bc8db&vjs=3
# https://www.indeed.com/rc/clk?jk=4c3895e736325e82&fccid=6a073cd614507165&vjs=3
# https://www.indeed.com/rc/clk?jk=371d30af8bc8cade&fccid=113517153f849886&vjs=3
# https://www.indeed.com/rc/clk?jk=ecc60f2cb1d91fd2&fccid=f770da67b3b51c62&vjs=3
# https://www.indeed.com/rc/clk?jk=433022743bacb7aa&fccid=126e3afd205caa95&vjs=3
# https://www.indeed.com/rc/clk?jk=09fbcda84d49ade2&fccid=73790d638c6583f2&vjs=3
# https://www.indeed.com/rc/clk?jk=5c41c3706c5737ab&fccid=2c937a614b823692&vjs=3
# https://www.indeed.com/rc/clk?jk=973beaba6cd9baec&fccid=5b8d10630cb111eb&vjs=3
# starting first 490 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=490
# 10
# https://www.indeed.com/rc/clk?jk=4b6db55958c57e0e&fccid=b9c291631ddbadd8&vjs=3
# https://www.indeed.com/rc/clk?jk=756d5075d4e5b05f&fccid=8fefdd19cc706a7c&vjs=3
# https://www.indeed.com/rc/clk?jk=3ce86ed0a07b2c2b&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=bade59ca3901edf7&fccid=4d94e1e385fd3960&vjs=3
# https://www.indeed.com/rc/clk?jk=04f896b9be09f77a&fccid=f4e7261d0c67c2b1&vjs=3
# https://www.indeed.com/rc/clk?jk=046f7758c7b1af1c&fccid=1f6abd1e4c7d27e7&vjs=3
# https://www.indeed.com/rc/clk?jk=e4974924bdf82e07&fccid=6b7a1dfe07e7f037&vjs=3
# https://www.indeed.com/rc/clk?jk=6eb9ed0592f68db6&fccid=db70737d31eac471&vjs=3
# https://www.indeed.com/rc/clk?jk=644c8573d9573b15&fccid=f82779f9f5d1aa9b&vjs=3
# https://www.indeed.com/rc/clk?jk=ac141759f79f8109&fccid=7942658690eba67c&vjs=3
# starting first 500 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=500
# 10
# https://www.indeed.com/rc/clk?jk=4f0516523bbebf69&fccid=8b9bafd9d608c198&vjs=3
# https://www.indeed.com/rc/clk?jk=9ddfc330dd084172&fccid=1f53b585e08311aa&vjs=3
# https://www.indeed.com/rc/clk?jk=e9cda25b2626ec64&fccid=f827d06dec9ae88b&vjs=3
# https://www.indeed.com/rc/clk?jk=371d30af8bc8cade&fccid=113517153f849886&vjs=3
# https://www.indeed.com/rc/clk?jk=1f56d2d0f937645e&fccid=40b2745438c9e5db&vjs=3
# https://www.indeed.com/rc/clk?jk=9103425c654429a3&fccid=4570e2216db4694f&vjs=3
# https://www.indeed.com/rc/clk?jk=340a8b65a73d689e&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=27559e7a73b5dbb7&fccid=53b041cb411b8ed4&vjs=3
# https://www.indeed.com/rc/clk?jk=25fdb451e484e5ec&fccid=48727ab8edac953b&vjs=3
# https://www.indeed.com/rc/clk?jk=fb9c4baf04e73635&fccid=8ba13cf21fd7c2de&vjs=3
# starting first 510 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=510
# 10
# https://www.indeed.com/rc/clk?jk=2c5cb2969c16d2ca&fccid=b6b16fcce9acaef1&vjs=3
# https://www.indeed.com/rc/clk?jk=f178db8a6c07c8dd&fccid=65a610215742c669&vjs=3
# https://www.indeed.com/rc/clk?jk=7598738a474017e8&fccid=3bc096a5907f15dd&vjs=3
# https://www.indeed.com/rc/clk?jk=5adfbbd303198452&fccid=4c069f49b73c7f31&vjs=3
# https://www.indeed.com/rc/clk?jk=f97a59f614d0c315&fccid=cc8e6e4f1597a7a8&vjs=3
# https://www.indeed.com/rc/clk?jk=8577b0300f603b76&fccid=fb556c90cb9bdb1a&vjs=3
# https://www.indeed.com/rc/clk?jk=6b17c06c40c3d1fb&fccid=b8fdf400786b78b1&vjs=3
# https://www.indeed.com/rc/clk?jk=8e1070d05f0609f4&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=10e5c6e9f7f439e0&fccid=3bcf7eb192e678e4&vjs=3
# https://www.indeed.com/rc/clk?jk=2e8bc746f6f059fb&fccid=3a7c8746beaa2452&vjs=3
# starting first 520 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=520
# 15
# https://www.indeed.com/rc/clk?jk=47e7e5b0d7da06bb&fccid=b544304db34cd3c6&vjs=3
# https://www.indeed.com/rc/clk?jk=5a5c2843eab04bd6&fccid=30cc7a5451d4ee77&vjs=3
# https://www.indeed.com/rc/clk?jk=350ddc9d1afe3ab9&fccid=96d230ef164ab31c&vjs=3
# https://www.indeed.com/rc/clk?jk=dea66e343c257e18&fccid=7eb0ae92a6869041&vjs=3
# https://www.indeed.com/rc/clk?jk=0dd09a1caa1c9087&fccid=53b041cb411b8ed4&vjs=3
# https://www.indeed.com/rc/clk?jk=cf94a3060eef795a&fccid=aef928e89977f7f0&vjs=3
# https://www.indeed.com/rc/clk?jk=f6353b8d8f2ae968&fccid=8630438014dc7c52&vjs=3
# https://www.indeed.com/rc/clk?jk=32b2b238a390ccb5&fccid=51dff8c345fc5c22&vjs=3
# https://www.indeed.com/rc/clk?jk=a5a72f4c6f5854f1&fccid=f5defb8af6e02778&vjs=3
# https://www.indeed.com/rc/clk?jk=0421ac22a7ffdd5d&fccid=e78b4d830917f0a9&vjs=3
# https://www.indeed.com/rc/clk?jk=7b8f4fcbfc50c6a1&fccid=e98373c75a9b8459&vjs=3
# ...
# starting first 800 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=800
# 10
# https://www.indeed.com/rc/clk?jk=0f6a645342030a36&fccid=2cc6cc6e00272158&vjs=3
# https://www.indeed.com/rc/clk?jk=ddfe097c8aa0d5fb&fccid=35424c139927dced&vjs=3
# https://www.indeed.com/rc/clk?jk=dd1842e8d66c0d75&fccid=84497107d8ab7c0d&vjs=3
# https://www.indeed.com/rc/clk?jk=6d5b4e2c9a60f35e&fccid=f904b5cd1be4cfad&vjs=3
# https://www.indeed.com/rc/clk?jk=3528a69b63bc29f4&fccid=5d3899b3741098f2&vjs=3
# https://www.indeed.com/rc/clk?jk=5f1057cadaa1b30c&fccid=de469d8ac5b42d90&vjs=3
# https://www.indeed.com/rc/clk?jk=ea3064dbbf998f16&fccid=3b89b9ec324f96c8&vjs=3
# https://www.indeed.com/rc/clk?jk=0e702ab701a1188c&fccid=dd616958bd9ddc12&vjs=3
# https://www.indeed.com/rc/clk?jk=db2859cbf88343d6&fccid=73e7cfa1796d463f&vjs=3
# https://www.indeed.com/rc/clk?jk=6a1cef3bf298c60f&fccid=3d0506c7b87d872a&vjs=3
# starting first 810 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=810
# 10
# https://www.indeed.com/rc/clk?jk=c925d8960857c8e4&fccid=5449d0b7b738a9c4&vjs=3
# https://www.indeed.com/rc/clk?jk=27827471569b4cfb&fccid=c4ba6202af4dda9d&vjs=3
# https://www.indeed.com/rc/clk?jk=81c3f78b42ebbf0f&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=9980212d6f9cc1e4&fccid=fac39a5e824d337d&vjs=3
# https://www.indeed.com/rc/clk?jk=859bd6e52ffef61a&fccid=8e5dab8caa064d1b&vjs=3
# https://www.indeed.com/rc/clk?jk=01a4dd47061e26bd&fccid=59237124d676ae4d&vjs=3
# https://www.indeed.com/rc/clk?jk=b9f33ca3d5ac7da2&fccid=dd3b0a1fc99fe359&vjs=3
# https://www.indeed.com/rc/clk?jk=22be3637f49f1a8a&fccid=0fbf324c877976f6&vjs=3
# https://www.indeed.com/rc/clk?jk=c8537e8db7cda54f&fccid=bf9f689e7d6d18c6&vjs=3
# https://www.indeed.com/rc/clk?jk=0b53b6007e1edb74&fccid=492d639d336fa9f3&vjs=3
# starting first 820 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=820
# 10
# https://www.indeed.com/rc/clk?jk=0916657ac2f9012e&fccid=124d2eb87a9084a3&vjs=3
# https://www.indeed.com/rc/clk?jk=819e832687afa720&fccid=d5f520113e118748&vjs=3
# https://www.indeed.com/rc/clk?jk=a81c4c47d5180b69&fccid=7bab4fa744cc39cd&vjs=3
# https://www.indeed.com/rc/clk?jk=6a1cef3bf298c60f&fccid=3d0506c7b87d872a&vjs=3
# https://www.indeed.com/rc/clk?jk=bf3107035c46d90d&fccid=74fbc768a4e5bece&vjs=3
# https://www.indeed.com/rc/clk?jk=bfb28a0293886ba4&fccid=2231941280824ce7&vjs=3
# https://www.indeed.com/rc/clk?jk=ae6fd0507667d081&fccid=2dda8667d8de78d8&vjs=3
# https://www.indeed.com/rc/clk?jk=2fb936f1fe24a9ea&fccid=3c41eea00c4f384f&vjs=3
# https://www.indeed.com/rc/clk?jk=59786585ec6110d9&fccid=6ce7730e12276932&vjs=3
# https://www.indeed.com/rc/clk?jk=3464c194bbac9279&fccid=caaf1a960095c607&vjs=3
# starting first 830 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=830
# 9
# https://www.indeed.com/rc/clk?jk=bae6281a65ac98fa&fccid=938c68fc89db4b9d&vjs=3
# https://www.indeed.com/rc/clk?jk=0d569ab949c419e0&fccid=40c24390c4fe6086&vjs=3
# https://www.indeed.com/rc/clk?jk=bfe6376855137893&fccid=47d1258571c3c9f7&vjs=3
# https://www.indeed.com/rc/clk?jk=ed284c6bb194e830&fccid=45f7e11d0973ee3a&vjs=3
# https://www.indeed.com/rc/clk?jk=d639e32ea6a2425d&fccid=b53218579f8cf88c&vjs=3
# https://www.indeed.com/rc/clk?jk=42123b50b8f8e49d&fccid=b6854e4a276db20a&vjs=3
# https://www.indeed.com/rc/clk?jk=6cd9cb8718b8b93b&fccid=59e636f9dffa6970&vjs=3
# https://www.indeed.com/rc/clk?jk=84b553d8d6e1f1c2&fccid=c87acfad54c63f2a&vjs=3
# https://www.indeed.com/rc/clk?jk=f37df1a7997d841f&fccid=eab52cccc4eb8127&vjs=3
# starting first 840 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=840
# 10
# https://www.indeed.com/rc/clk?jk=49999ffe7f60cbb9&fccid=e9f1decdeceb0168&vjs=3
# https://www.indeed.com/rc/clk?jk=58ac078b33b64b50&fccid=5b735a37fa93d93f&vjs=3
# https://www.indeed.com/rc/clk?jk=a519d35771c9d16b&fccid=ebd944f3c244d667&vjs=3
# https://www.indeed.com/rc/clk?jk=e567f19aaa20cfff&fccid=1b3c0eb3b7fdba77&vjs=3
# https://www.indeed.com/rc/clk?jk=074034cfb012b6f8&fccid=518acc75d1476dc2&vjs=3
# https://www.indeed.com/rc/clk?jk=7484b7a64a397f9c&fccid=c0bee8a999a0cf0a&vjs=3
# https://www.indeed.com/rc/clk?jk=915a04b00fd96ae8&fccid=451a594b449eb102&vjs=3
# https://www.indeed.com/rc/clk?jk=41b3e5a54e608d33&fccid=667ba717ce627077&vjs=3
# https://www.indeed.com/rc/clk?jk=2be88d1b6c94b3e3&fccid=f20a2b00c43b0bec&vjs=3
# https://www.indeed.com/rc/clk?jk=e7eb2ef0cae6168d&fccid=b276df3fa16c132a&vjs=3
# starting first 850 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=850
# 10
# https://www.indeed.com/rc/clk?jk=5d3a277f46e326ca&fccid=7942658690eba67c&vjs=3
# https://www.indeed.com/rc/clk?jk=7280f7302072dd50&fccid=105ecfd0283f415f&vjs=3
# https://www.indeed.com/rc/clk?jk=a4f65e42dfa4b41f&fccid=4f5d36415138e9f5&vjs=3
# https://www.indeed.com/rc/clk?jk=5d5909ccc1854317&fccid=1faa299cbcd35ef2&vjs=3
# https://www.indeed.com/rc/clk?jk=350ddc9d1afe3ab9&fccid=96d230ef164ab31c&vjs=3
# https://www.indeed.com/rc/clk?jk=cee70e1ffc71ac9f&fccid=cead9d6164d78b3a&vjs=3
# https://www.indeed.com/rc/clk?jk=abab59c2ae227bf6&fccid=ef4be98af276034b&vjs=3
# https://www.indeed.com/rc/clk?jk=1a3a361c5462e714&fccid=bc51f56762438d6f&vjs=3
# https://www.indeed.com/rc/clk?jk=de0885f57b2e2f59&fccid=570de3d15b9bbb97&vjs=3
# https://www.indeed.com/rc/clk?jk=89125bf9ba75fcd6&fccid=5bcd1ef0a7f4fb99&vjs=3
# starting first 860 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=860
# 10
# https://www.indeed.com/rc/clk?jk=5fa7b57be7910ab4&fccid=206f464dc90cc539&vjs=3
# https://www.indeed.com/rc/clk?jk=c9a4aeebc79e3d21&fccid=e87c07079f6e369f&vjs=3
# https://www.indeed.com/rc/clk?jk=f989349b8257849a&fccid=bf9f689e7d6d18c6&vjs=3
# https://www.indeed.com/rc/clk?jk=19fa93f265fd0e30&fccid=97bfb79867bd9b23&vjs=3
# https://www.indeed.com/rc/clk?jk=951b54de6225d136&fccid=be0461c63dffd1b8&vjs=3
# https://www.indeed.com/rc/clk?jk=2961dd6ac8e6360b&fccid=fc68da685e8aa986&vjs=3
# https://www.indeed.com/rc/clk?jk=1878970f7bdf1215&fccid=13d7d7c1ce07347e&vjs=3
# https://www.indeed.com/rc/clk?jk=06065ad00bb835bd&fccid=e65a7f54f32082bd&vjs=3
# https://www.indeed.com/rc/clk?jk=8598e18b3ddb059f&fccid=14b5a49956ef18fa&vjs=3
# https://www.indeed.com/rc/clk?jk=d3a61dbc8cc57ecc&fccid=ee968c74fe6ee0b2&vjs=3
# starting first 870 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=870
# 9
# https://www.indeed.com/rc/clk?jk=95e88a2b520e4971&fccid=58aac7d4a0aa0264&vjs=3
# https://www.indeed.com/rc/clk?jk=c1efdd7883606e3d&fccid=212bd0e1a939f8db&vjs=3
# https://www.indeed.com/rc/clk?jk=12c1dc4c5090a8c2&fccid=4babd1d283bc6add&vjs=3
# https://www.indeed.com/rc/clk?jk=90b5f99d577800b7&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=ac563b2f471261c8&fccid=bc18dc50336f5711&vjs=3
# https://www.indeed.com/rc/clk?jk=f3e21abc1018f5fd&fccid=1b20c576e5a4bddb&vjs=3
# https://www.indeed.com/rc/clk?jk=67e3aff4e174791e&fccid=be3b11aa573faee7&vjs=3
# https://www.indeed.com/rc/clk?jk=dc9ab0f85eda3972&fccid=87296c430fc584e1&vjs=3
# https://www.indeed.com/rc/clk?jk=5bd6b30221647543&fccid=b635c6c8bd1e0ed6&vjs=3
# starting first 880 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=880
# 10
# https://www.indeed.com/rc/clk?jk=27d05f62c14c79da&fccid=312941d745eb270b&vjs=3
# https://www.indeed.com/rc/clk?jk=0f897d8d6ce1b415&fccid=af82f506ed7ea7e1&vjs=3
# https://www.indeed.com/rc/clk?jk=819e832687afa720&fccid=d5f520113e118748&vjs=3
# https://www.indeed.com/rc/clk?jk=9ff8354c7fb5897c&fccid=ec798be206d0335c&vjs=3
# https://www.indeed.com/rc/clk?jk=7d373364b10af040&fccid=727235324836b166&vjs=3
# https://www.indeed.com/rc/clk?jk=dd7f0c004a21cef2&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=e5d5382ea2b314b5&fccid=dd616958bd9ddc12&vjs=3
# https://www.indeed.com/rc/clk?jk=2fc99c3f7688198d&fccid=7db14b470ed12322&vjs=3
# https://www.indeed.com/rc/clk?jk=01af73c991b03c91&fccid=a6a761b598113fc6&vjs=3
# https://www.indeed.com/rc/clk?jk=6db01c3c5addbc3c&fccid=cc0919f84b5fb6ac&vjs=3
# starting first 890 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=890
# 10
# https://www.indeed.com/rc/clk?jk=e7c5d1cf73cecebc&fccid=6374759aed463ee1&vjs=3
# https://www.indeed.com/rc/clk?jk=f88b3cde7fc2c8ff&fccid=d3276368e64f1450&vjs=3
# https://www.indeed.com/rc/clk?jk=f758d4ae7c633351&fccid=6c057ad5b12fabbd&vjs=3
# https://www.indeed.com/rc/clk?jk=d613431f3836719e&fccid=546eca89ab8f5931&vjs=3
# https://www.indeed.com/rc/clk?jk=2ba699865b85bec6&fccid=b8b24773975b4576&vjs=3
# https://www.indeed.com/rc/clk?jk=bd59f2f0804782b7&fccid=66d394411dd2efad&vjs=3
# https://www.indeed.com/rc/clk?jk=64db012ea169342c&fccid=f2bbc2a882eaed7c&vjs=3
# https://www.indeed.com/rc/clk?jk=fc2d1daf29711693&fccid=3d93143c99ff89a3&vjs=3
# https://www.indeed.com/rc/clk?jk=77837f30e77b3c88&fccid=0c39fb2c91742dcf&vjs=3
# https://www.indeed.com/rc/clk?jk=0ddc1565947c7b58&fccid=8bae0fba3b920ea8&vjs=3
# starting first 900 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=900
# 10
# https://www.indeed.com/rc/clk?jk=e13490b92a86061a&fccid=ae0c894528aa6eee&vjs=3
# https://www.indeed.com/rc/clk?jk=01795468dbdc4c56&fccid=06206ab329e0eb22&vjs=3
# https://www.indeed.com/rc/clk?jk=41c8d45a22c0f87b&fccid=16b28e3f56f6cf9b&vjs=3
# https://www.indeed.com/rc/clk?jk=9961604a96c15bfd&fccid=feaabf8e6a699d3c&vjs=3
# https://www.indeed.com/rc/clk?jk=e3006dc0b646b6d3&fccid=92278e592a11e3a5&vjs=3
# https://www.indeed.com/rc/clk?jk=a9b413ae508b9357&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=ca2c1443464b6ff7&fccid=1e01277d9001512a&vjs=3
# https://www.indeed.com/rc/clk?jk=4fd4ae6b3ba7776f&fccid=07c9da759d4e678a&vjs=3
# https://www.indeed.com/rc/clk?jk=35247a368b8d84f5&fccid=ce4e6cf83cbd6851&vjs=3
# https://www.indeed.com/rc/clk?jk=0916657ac2f9012e&fccid=124d2eb87a9084a3&vjs=3
# starting first 910 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=910
# 10
# https://www.indeed.com/rc/clk?jk=d56b0dfbdb7c5aa3&fccid=7077d7e88049c02a&vjs=3
# https://www.indeed.com/rc/clk?jk=d3a4dcce96a94ac2&fccid=3a71a4d2f7990a25&vjs=3
# https://www.indeed.com/rc/clk?jk=7e019bbe33a196a0&fccid=39baf972ba156d41&vjs=3
# https://www.indeed.com/rc/clk?jk=7d0beb2c2524edc3&fccid=f37af6e0eae53880&vjs=3
# https://www.indeed.com/rc/clk?jk=14815c19cc272266&fccid=854b6265d5210a19&vjs=3
# https://www.indeed.com/rc/clk?jk=7d9972ac52ba5c7e&fccid=380ef847cc5dfc1f&vjs=3
# https://www.indeed.com/rc/clk?jk=178789595a909a8b&fccid=7f90bc77737eeea4&vjs=3
# https://www.indeed.com/rc/clk?jk=c139deab234eca8e&fccid=212bd0e1a939f8db&vjs=3
# https://www.indeed.com/rc/clk?jk=7f1e42c244d50286&fccid=62d0bf8f2d130eaa&vjs=3
# https://www.indeed.com/rc/clk?jk=fcc3c58ff68e9b21&fccid=c1099851e9794854&vjs=3
# starting first 920 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=920
# 10
# https://www.indeed.com/rc/clk?jk=1ec9d924cc2a452e&fccid=f1557471a26b6171&vjs=3
# https://www.indeed.com/rc/clk?jk=46a3d13d956ab4bd&fccid=7136762d065a5ad7&vjs=3
# https://www.indeed.com/rc/clk?jk=690280bead761573&fccid=6328b27691d3fdc3&vjs=3
# https://www.indeed.com/rc/clk?jk=901fb6a023bb7f12&fccid=dcf1eb2d7950bbb8&vjs=3
# https://www.indeed.com/rc/clk?jk=160f292ca2d3a8cd&fccid=3c41eea00c4f384f&vjs=3
# https://www.indeed.com/rc/clk?jk=47e7e5b0d7da06bb&fccid=b544304db34cd3c6&vjs=3
# https://www.indeed.com/rc/clk?jk=2fc99c3f7688198d&fccid=7db14b470ed12322&vjs=3
# https://www.indeed.com/rc/clk?jk=c31a1fa4eac572f2&fccid=ab0ef6192557a06f&vjs=3
# https://www.indeed.com/rc/clk?jk=6455d0bbd6b5f2c0&fccid=8a2313e992935dec&vjs=3
# starting first 930 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=930
# 10
# https://www.indeed.com/rc/clk?jk=47846c72fd3f1750&fccid=9c5c8ea47ff967bb&vjs=3
# https://www.indeed.com/rc/clk?jk=90b5f99d577800b7&fccid=8ce3cf8e1e3ddd14&vjs=3
# https://www.indeed.com/rc/clk?jk=4787f416f961cfac&fccid=82e5b284fc9e323c&vjs=3
# https://www.indeed.com/rc/clk?jk=392a257e640ab446&fccid=92f1ccd9154b0139&vjs=3
# https://www.indeed.com/rc/clk?jk=3fa030dc19360b98&fccid=f5d70f2068a98143&vjs=3
# https://www.indeed.com/rc/clk?jk=ecacf58f2f41884b&fccid=b6a22a06e345134a&vjs=3
# https://www.indeed.com/rc/clk?jk=d8094af2320c5308&fccid=7f8125e7334ff72c&vjs=3
# https://www.indeed.com/rc/clk?jk=e3a097a242791da8&fccid=a7fb9f44c6fec7d5&vjs=3
# https://www.indeed.com/rc/clk?jk=b93f0ea0ef7c1c63&fccid=6cdebd3a6977c60b&vjs=3
# https://www.indeed.com/rc/clk?jk=b05926bf9a4274ed&fccid=7fc6d3992188a532&vjs=3
# starting first 940 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=940
# 10
# https://www.indeed.com/rc/clk?jk=c732fe1a8465a939&fccid=4933428573b6578c&vjs=3
# https://www.indeed.com/rc/clk?jk=c503ad970523765c&fccid=7936be8709f0fc98&vjs=3
# https://www.indeed.com/rc/clk?jk=d440701772ae0d50&fccid=dd616958bd9ddc12&vjs=3
# https://www.indeed.com/rc/clk?jk=b3fcfeb77005c254&fccid=fbdd0b7e6ecfe4ce&vjs=3
# https://www.indeed.com/rc/clk?jk=40bf4a3314f7178f&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=92cb41b5c53fc111&fccid=9c094dedde5fb497&vjs=3
# https://www.indeed.com/rc/clk?jk=e0f5f7584523081a&fccid=59c8e3e7017ea02a&vjs=3
# https://www.indeed.com/rc/clk?jk=1f02a6ad6fe39089&fccid=7077d7e88049c02a&vjs=3
# https://www.indeed.com/rc/clk?jk=ff85facfdd26cbc3&fccid=6eed2b093d6f782d&vjs=3
# https://www.indeed.com/rc/clk?jk=2eebe0132f2f5e1f&fccid=69247daab4a84a92&vjs=3
# starting first 950 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=950
# 10
# https://www.indeed.com/rc/clk?jk=2726aae600144780&fccid=200a825acadb9338&vjs=3
# https://www.indeed.com/rc/clk?jk=65a9718a91ed9001&fccid=ad1a8689c9e14503&vjs=3
# https://www.indeed.com/rc/clk?jk=faaaaa4ba2e052b4&fccid=818404f6124eefd5&vjs=3
# https://www.indeed.com/rc/clk?jk=4ca4f65362beaa71&fccid=c1099851e9794854&vjs=3
# https://www.indeed.com/rc/clk?jk=a81c4c47d5180b69&fccid=7bab4fa744cc39cd&vjs=3
# https://www.indeed.com/rc/clk?jk=b8a2cb8996dddecb&fccid=3a58a6877f80f179&vjs=3
# https://www.indeed.com/rc/clk?jk=745baedd84ea2190&fccid=a16ad66720e7c358&vjs=3
# https://www.indeed.com/rc/clk?jk=087ffa8fbe85a53d&fccid=fe2d21eef233e94a&vjs=3
# https://www.indeed.com/rc/clk?jk=33c1187a3ef6a4af&fccid=91852703289ad7d4&vjs=3
# https://www.indeed.com/rc/clk?jk=28a8b2988d3e0ffe&fccid=adb435e920a31078&vjs=3
# starting first 960 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=960
# 10
# https://www.indeed.com/rc/clk?jk=b2b1fe1ccedde44d&fccid=9f2bb83bd9bfe2fc&vjs=3
# https://www.indeed.com/rc/clk?jk=44fa5c6428db78c1&fccid=3b6b59a9d7caadd8&vjs=3
# https://www.indeed.com/rc/clk?jk=64db012ea169342c&fccid=f2bbc2a882eaed7c&vjs=3
# https://www.indeed.com/rc/clk?jk=1938df5c42293a29&fccid=200a825acadb9338&vjs=3
# https://www.indeed.com/rc/clk?jk=68fca3733cec9abd&fccid=d81ffc39c84ae85d&vjs=3
# https://www.indeed.com/rc/clk?jk=83494535c63612ee&fccid=1639254ea84748b5&vjs=3
# https://www.indeed.com/rc/clk?jk=fa0f0747dbe6bc51&fccid=3a0ed1469bf33656&vjs=3
# https://www.indeed.com/rc/clk?jk=45c408948eb7b370&fccid=b1bd9b34a39d5dcd&vjs=3
# https://www.indeed.com/rc/clk?jk=6ed3bbf2d1095475&fccid=bcddd4edac344549&vjs=3
# https://www.indeed.com/rc/clk?jk=9438a02600dc4575&fccid=6b7a1dfe07e7f037&vjs=3
# starting first 970 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=970
# 10
# https://www.indeed.com/rc/clk?jk=f8c76ea2a122596a&fccid=1a3d78ddf45c0b3f&vjs=3
# https://www.indeed.com/rc/clk?jk=72a735ed83622c43&fccid=1f92178814b05d89&vjs=3
# https://www.indeed.com/rc/clk?jk=45c7f8c9e819c9b4&fccid=add6d0a1c3e02a8a&vjs=3
# https://www.indeed.com/rc/clk?jk=209c414209a6a119&fccid=64eee9c93d9ef045&vjs=3
# https://www.indeed.com/rc/clk?jk=6f1dcc60c9b8da86&fccid=2d136843920e75a6&vjs=3
# https://www.indeed.com/rc/clk?jk=e18cbb3be5006e92&fccid=5754691be39e4be7&vjs=3
# https://www.indeed.com/rc/clk?jk=0986376e9b3ae9dc&fccid=5cb727313a823dd6&vjs=3
# https://www.indeed.com/rc/clk?jk=d3c3edc7a56aba09&fccid=5bd99dfa21c8a490&vjs=3
# https://www.indeed.com/rc/clk?jk=c94622daf05aefb0&fccid=c1099851e9794854&vjs=3
# https://www.indeed.com/rc/clk?jk=5b28974bbc0c1daf&fccid=f9233b434704df2c&vjs=3
# starting first 980 of data analyst
# https://www.indeed.com/jobs?q="data+analyst"&start=980
# 10
# https://www.indeed.com/rc/clk?jk=bbaa0a7dba08b2f7&fccid=3326a5ad8d5aa81b&vjs=3
# https://www.indeed.com/rc/clk?jk=6b1a508024e221f2&fccid=d455b737dea6e4d9&vjs=3
# https://www.indeed.com/rc/clk?jk=42f52a81d96b738d&fccid=8e5415c099aa948c&vjs=3

# %% [markdown]
# ## Preparing the data
#
# For convenience I have scraped the job openings of 4 job titles and put them in a csv so I don't have to run the scraper every session (it takes some time to complete).
#
# First, load the csv and randomize

# %%
df = pd.read_csv('data/data-set.csv')
df = df.sample(frac=1).reset_index(drop=True)

conditions = [
    (df['labels'] == 'data scientist'),
    (df['labels'] == 'sales manager'),
    (df['labels'] == 'front-office manager'),
    (df['labels'] == 'front-end developer')]
choices = [0, 1, 2, 3]
df['labels_num'] = np.select(conditions, choices) # make label column numerica

jobs = df['jobs'].to_numpy()
labels = df['labels_num'].to_numpy()

# %% [markdown]
# Then, remove the stopwords

# %%
jobs_clean = []

for i in jobs:
    job = i
    for word in STOPWORDS:
        token = ' ' + word + ' '
        job = job.replace(token, ' ')
        job = job.replace(' ', ' ')
    jobs_clean.append(job)

# %% [markdown]
# Then, set our paramaters

# %%
vocab_size = 8000 # most common words
embedding_dim = 64
max_length = 600
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>' # not in word index
training_portion = .8 # portion of training set

# %% [markdown]
# One-hot-encode label column

# %%
labels = tf.keras.utils.to_categorical(labels, num_classes=4)

# %% [markdown]
# Convert them to a train and test set

# %%
train_size = int(len(jobs_clean) * training_portion)

train_jobs = jobs_clean[0: train_size]
train_labels = labels[0: train_size]

validation_jobs = jobs_clean[train_size:]
validation_labels = labels[train_size:]

print(train_size)
print(len(train_jobs))
print(len(train_labels))
print(len(validation_jobs))
print(len(validation_labels))

# %% [markdown]
# Tokenizer
#
# OOV is the most common, followed by experience, etc.

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_jobs)
word_index = tokenizer.word_index
dict(list(word_index.items())[0:10])

# %% [markdown]
# Turn into list of sequence

# %%
train_sequences = tokenizer.texts_to_sequences(train_jobs)
print(train_sequences[10]) # 11th job opening

# %%
type(train_jobs)

# %%
train_sequences[0]

# %% [markdown]
# Pad sequences so they are all the same size. train_padded is length 500

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(len(train_sequences[0])) # old
print(len(train_padded[0])) # new

print(len(train_sequences[1]))
print(len(train_padded[1]))

print(len(train_sequences[10]))
print(len(train_padded[10]))

# %% [markdown]
# Do the same for validation sequences

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_jobs)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

print(len(validation_sequences))
print(validation_padded.shape)

# %% [markdown]
# Compare original job text and job text after padding and tokenization

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_job(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
print(decode_job(train_padded[12]))
print('---')
print(train_jobs[12])

# %% [markdown]
# ## Building the model

# %% [markdown]
# ## Try #1 - Stacked LSTM layers

# %%
# vocab_size = 8000 # most common words
# embedding_dim = 64
# max_length = 600

# %%
model = tf.keras.Sequential([
    # Add an Embedding layer expecting input vocab of size 8000, and output embedding dimension of size 64 we set at the top
    tf.keras.layers.Embedding(vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, return_sequences=True)),
    # Extra LSTM layer
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    # use ReLU in place of tanh function since they are very good alternatives of each other.
    tf.keras.layers.Dense(embedding_dim, activation='relu'),
    # Add a Dense layer with 4 nodes (1 for each class) and softmax activation.
    # When we have multiple outputs, softmax convert outputs layers into a probability distribution.
    tf.keras.layers.Dense(4, activation='softmax')
])
model.summary()

# %%
train_padded_array = np.asarray(train_padded)


model.compile(loss='categorical_croentropy', optimizer='adam', metrics=['accuracy'])
num_epochs = 50
history = model.fit(train_padded, train_labels, epochs=num_epochs, validation_data=(validation_padded, validation_labels), verbose=2)

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# A big gap between val_loss and training loss, indicating overfit

# %% [markdown]
# ## Try #2 - Very simple single LSTM layer

# %%
# vocab_size = 8000 # most common words
# embedding_dim = 64
# max_length = 600

# %%
model = tf.keras.Sequential([
    # Add an Embedding layer expecting input vocab of size 8000, and output embedding dimension of size 64 we set at the top
    tf.keras.layers.Embedding(vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    # use ReLU in place of tanh function since they are very good alternatives of each other.
    tf.keras.layers.Dense(embedding_dim, activation='relu'),
    # Add a Dense layer with 4 nodes (1 for each class) and softmax activation.
    # When we have multiple outputs, softmax convert outputs layers into a probability distribution.
    tf.keras.layers.Dense(4, activation='softmax')
])
model.summary()

# %%
train_padded_array = np.asarray(train_padded)


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
num_epochs = 5
history = model.fit(train_padded, train_labels, epochs=num_epochs, validation_data=(validation_padded, validation_labels), verbose=2)

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Save model

# %%
model.save('model/model1.h5')

# %%
import pickle

# saving
with open('model/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('model/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# ## CV inlezen

# %%
import docx

doc =  docx.Document('data/CV_robinfaber.docx')

# %%
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text.replace('\t', ' '))
    return ' '.join(fullText)

# %%
text = getText('data/CV_robinfaber.docx')

# %%
type(text)

# %%
for i in text:
    job = i
    for word in STOPWORDS:
        token = ' ' + word + ' '
        job = job.replace(token, ' ')
        job = job.replace(' ', ' ')
    jobs_clean.append(job)

# %%
seq = tokenizer.texts_to_sequences(text)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['data scientist', 'sales manager', 'front-office manager', 'front-end developer']
print(pred, labels[np.argmax(pred)])

# %%
padded

# %%
np.argmax(pred)

# %%
seq
